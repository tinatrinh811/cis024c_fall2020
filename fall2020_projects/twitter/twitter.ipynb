# %% [markdown]
# # CIS-024C Fall 2020 - Twitter Project

# %% [markdown]
# ### Use the Twitter library tweepy to retrieve a set of tweets from the internet.
#
# Once you have read the tweets in your program, implement the following
#
# 1. Set filters on 4 of your favorite politicians and create a pie chart showing how many tweets of each of them you were able to gather in a 4 hour period.
# 2. Create a bar chart showing the number of tweets each politician received during each of the 4 hours.
# More information on how to do this can be found here
#
# http://docs.tweepy.org/en/v3.5.0/
#
# Total Points: 100
#
# #### Rubric:
# 1. Reading in tweets and setting the right filters - 40 points
# 2. Create a pie chart showing how many tweets of each of them you were able to gather in a 4 hour period - 30 points
# 3.  Create a bar chart showing the number of tweets each politician received during each of the 4 hours - 30 points

# %%
### YOUR CODE GOES BELOW

#See https://nocodewebscraping.com/twitter-json-examples/
# To get keys - https://apps.twitter.com
# To install tweepy use 'pip install tweepy'

consumer_key = 'ihRlWGUJq6yZxkoX3ommEwT9F'
consumer_secret = 'dZFgUUO5gYl9C4UFWKDVuWleK5MdoZb0R9lYNg3ml4u4cjZB1P'
access_token = '4201552152-ef6YxXfZGep736M0mUIpbkHlZDcxJWTM2KmYUgm'
access_token_secret = 'XC2rJ6IecQuZcqC86cblfkPK6lmwx71QTQH4a6TbgYUJQ'

import tweepy #https://github.com/tweepy/tweepy
import json

# This is the listener, resposible for receiving data
class StdOutListener(tweepy.StreamListener):
    
    def __init__(self, f):
        super(StdOutListener, self).__init__()
        self._f = f
        
    def on_data(self, data):
        
        self._f.write(data)
        
    def on_status(self,status):
        
        print(status)
        self._f.write(status.text)

        '''
        decoded = json.loads(data)
        #open a file to store the status objects
        file = open('./stream.json', 'a')  
        #write json to file
        json.dump(decoded,file,sort_keys = True,indent = 4)
        #show progress
        print("Writing tweets to file,CTRL+C to terminate the program")
        '''

        return True

    def on_error(self, status):
        printf(status)
        self._f.write(status.text)

if __name__ == '__main__':

    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    # There are different kinds of streams: public stream, user stream, multi-user streams
    # For more details refer to https://dev.twitter.com/docs/streaming-apis
    
    with open('./stream.json','w') as f:
        
        # initialize listener and pass in file handle
        l = StdOutListener(f)
        
        # create stream object
        stream = tweepy.Stream(auth, l)
        
        #Hashtag to filter
        stream.filter(track=["#georgia"])

### END CODE
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-6a34439d3a46> in <module>
#      62
#      63         #Hashtag to filter
# ---> 64         stream.filter(track=["#georgia"])
#      65
#      66 ### END CODE
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
## Read JSON data from file

import json

tweetsList = []

with open('./stream.json') as f:
    for jsonObj in f:
        tweetDict = json.loads(jsonObj)
        tweetsList.append(tweetDict)

print("Displaying Tweets:\n")
print("Number of Tweets in list:", len(tweetsList))
for tweet in tweetsList:
    print("\n Tweet Id:%d\n Favorite Count:%d \n Retweet Count:%d\n Text: %s\n Timestamp:%s" %\
          (tweet["id"],  tweet["favorite_count"], tweet["retweet_count"], tweet["text"][:100],tweet["timestamp_ms"])\
         )
# Out:
# Displaying Tweets:
#
# Number of Tweets in list: 30
#
#  Tweet Id:1335793272762093569
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @intheMatrixxx: #Georgia has a Chinese website featuring Govenor @BrianKempGA who is asking for i
#  Timestamp:1607312908722
#
#  Tweet Id:1335793272950808576
#  Favorite Count:0
#  Retweet Count:0
#  Text: #Georgia #GeorgiaSenate
#  Timestamp:1607312908767
#
#  Tweet Id:1335793273831473152
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @jfradioshow: Breaking  #Monday Live From #Athens #Georgia Alfredo Ortiz 6:15, Dr. @RogerDKlein 7
#  Timestamp:1607312908977
#
#  Tweet Id:1335793276360790017
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @intheMatrixxx: #Georgia has a Chinese website featuring Govenor @BrianKempGA who is asking for i
#  Timestamp:1607312909580
#
#  Tweet Id:1335793276603887616
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @adjunctprofesor: Voters Organized for Trusted Election Results in #Georgia (VOTERGA) is pushing
#  Timestamp:1607312909638
#
#  Tweet Id:1335793285487538178
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @intheMatrixxx: #Georgia has a Chinese website featuring Govenor @BrianKempGA who is asking for i
#  Timestamp:1607312911756
#
#  Tweet Id:1335793288717230080
#  Favorite Count:0
#  Retweet Count:0
#  Text: Unbelievable.  How many Georgia citizens know this?
#  Timestamp:1607312912526
#
#  Tweet Id:1335793289094549508
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @PandaTribune: We've got momentum! HOLD THE LINE!🇺🇸
#
# "The petition serves as notification to Gov.
#  Timestamp:1607312912616
#
#  Tweet Id:1335793289207947267
#  Favorite Count:0
#  Retweet Count:0
#  Text: "In the last debate with Jon Ossoff, Senator Perdue was represented by an EMPTY SUIT." #PerdueChicke
#  Timestamp:1607312912643
#
#  Tweet Id:1335793292517130241
#  Favorite Count:0
#  Retweet Count:0
#  Text: @EWErickson It's unlikely that Pastor Warnock is a "commie", or a socialist. Just like Biden after 4
#  Timestamp:1607312913432
#
#  Tweet Id:1335793297424601088
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @TeamTrump: LIVE: President Trump in Valdosta, GA #Valdosta #Georgia https://t.co/P1OyvbQeUg
#  Timestamp:1607312914602
#
#  Tweet Id:1335793301748920321
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @erinebal29: @HeyTammyBruce @JennaEllisEsq @LegInsurrection https://t.co/gBj3B3c6Ol.  Perhaps @Go
#  Timestamp:1607312915633
#
#  Tweet Id:1335793304059961344
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @adjunctprofesor: .@POTUS
# .@SidneyPowell1
# .@LLinWood
# .@GenFlynn
# .@CodeMonkeyZ
# #ElectionIntegrityM
#  Timestamp:1607312916184
#
#  Tweet Id:1335793306282835973
#  Favorite Count:0
#  Retweet Count:0
#  Text: #GeorgiaSenateRunoffDebate
#
# Unbelievable. Why isn’t David Perdue at the damn debate? He’s the curre
#  Timestamp:1607312916714
#
#  Tweet Id:1335793310313615361
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @SidneyPowell1: #Georgia progress! Demand special session and full forensic investigation. No #Do
#  Timestamp:1607312917675
#
#  Tweet Id:1335793319624933377
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @disclosetv: NEW - #Georgia has a Chinese website featuring Govenor @BrianKempGA who is asking fo
#  Timestamp:1607312919895
#
#  Tweet Id:1335793319843127296
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @MelissaLeggett4: Sell outs everywhere
#  Timestamp:1607312919947
#
#  Tweet Id:1335793320598102016
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @disclosetv: NEW - #Georgia has a Chinese website featuring Govenor @BrianKempGA who is asking fo
#  Timestamp:1607312920127
#
#  Tweet Id:1335793320900108289
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @ZemanLynnZ: @MollyJongFast @joemac1114 No contest.
#
# #Georgia #WarnockForSenate #WarnockForGeorg
#  Timestamp:1607312920199
#
#  Tweet Id:1335793323664166912
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @johnloudon: The defensive “Republican”official in charge of the embarrassing #Georgia systemic #
#  Timestamp:1607312920858
#
#  Tweet Id:1335793331775950848
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @intheMatrixxx: #Georgia has a Chinese website featuring Govenor @BrianKempGA who is asking for i
#  Timestamp:1607312922792
#
#  Tweet Id:1335793335651495936
#  Favorite Count:0
#  Retweet Count:0
#  Text: @elenaparent #Georgia #ElectionFraud
#  Timestamp:1607312923716
#
#  Tweet Id:1335793337417261058
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @CodeMonkeyZ: Lets do a pop quiz.
#
# If you take blood money, you usually end up paying in ________
#  Timestamp:1607312924137
#
#  Tweet Id:1335793349404585989
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @CodeMonkeyZ: Lets do a pop quiz.
#
# If you take blood money, you usually end up paying in ________
#  Timestamp:1607312926995
#
#  Tweet Id:1335793354353864704
#  Favorite Count:0
#  Retweet Count:0
#  Text: WTF?!? @senatorlaughlin did u see this?
# @OGPatriot1776
#  Timestamp:1607312928175
#
#  Tweet Id:1335793358976012289
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @CodeMonkeyZ: Lets do a pop quiz.
#
# If you take blood money, you usually end up paying in ________
#  Timestamp:1607312929277
#
#  Tweet Id:1335793361828028416
#  Favorite Count:0
#  Retweet Count:0
#  Text: @KamalaHarris The most effective way to get America healthy again, stop the pandemic, &amp; get peop
#  Timestamp:1607312929957
#
#  Tweet Id:1335793365238112258
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @ArchKennedy: “The FBI Is Nowhere to be Found‼️” – @RudyGiuliani Reveals UNDENIABLE VOTER FRAUD i
#  Timestamp:1607312930770
#
#  Tweet Id:1335793366458634240
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @PandaTribune: We've got momentum! HOLD THE LINE!🇺🇸
#
# "The petition serves as notification to Gov.
#  Timestamp:1607312931061
#
#  Tweet Id:1335793367876300800
#  Favorite Count:0
#  Retweet Count:0
#  Text: RT @MelissaLeggett4: Sell outs everywhere
#  Timestamp:1607312931399
